# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("Merged_data.tsv", sep ="\t", header= 0)
data.head()
# Out:
#   Fraction_Size Depth Lakes_names                             Assembly  \
# 0             S     E        AMAD  AMADE-SM-01apr22.megahit.nv.contigs
# 1             S     E        AMAD  AMADE-SM-06sep21.megahit.nv.contigs
# 2             S     H        AMAD  AMADH-SM-01apr22.megahit.nv.contigs
# 3             S     H        AMAD  AMADH-SM-06sep21.megahit.nv.contigs
# 4           NaN   NaN         NaN                                  NaN
#
#     contigs (>= 0 bp)   contigs (>= 1000 bp)   contigs (>= 5000 bp)  \
# 0           1774485.0               278227.0                20575.0
# 1           1831137.0               260435.0                26462.0
# 2           1703800.0               245658.0                24012.0
# 3           2239190.0               287218.0                27548.0
# 4                 NaN                    NaN                    NaN
#
#     contigs (>= 10000 bp)   contigs (>= 25000 bp)   contigs (>= 50000 bp)  \
# ...

# %%
data = data.dropna(subset=['Lakes_names'])
data
# Out:
#     Fraction_Size Depth Lakes_names                             Assembly  \
# 0               S     E        AMAD  AMADE-SM-01apr22.megahit.nv.contigs
# 1               S     E        AMAD  AMADE-SM-06sep21.megahit.nv.contigs
# 2               S     H        AMAD  AMADH-SM-01apr22.megahit.nv.contigs
# 3               S     H        AMAD  AMADH-SM-06sep21.megahit.nv.contigs
# 5               S     E        ARCA  ARCAE-SM-04apr22.megahit.nv.contigs
# ..            ...   ...         ...                                  ...
# 546             S     E        ZURI  ZURIE-SM-02sep20.megahit.nv.contigs
# 547             S     E        ZURI  ZURIE-SM-04may22.megahit.nv.contigs
# 548             L     H        ZURI  ZURIH-LM-02sep20.megahit.nv.contigs
# 549             S     H        ZURI  ZURIH-SM-02sep20.megahit.nv.contigs
# 550             S     H        ZURI  ZURIH-SM-04may22.megahit.nv.contigs
#
#       contigs (>= 0 bp)   contigs (>= 1000 bp)   contigs (>= 5000 bp)  \
# ...

# %%
data.describe()
# Out:
#         contigs (>= 0 bp)   contigs (>= 1000 bp)   contigs (>= 5000 bp)  \
# count        4.750000e+02             475.000000             475.000000
# mean         2.918857e+06          381646.696842           29627.501053
# std          1.101366e+06          118725.434269            8741.009483
# min          7.332000e+04            2971.000000              12.000000
# 25%          2.160710e+06          306885.000000           24637.000000
# 50%          2.842630e+06          386015.000000           29086.000000
# 75%          3.710746e+06          451150.500000           35051.000000
# max          6.251737e+06          778585.000000           63584.000000
#
#         contigs (>= 10000 bp)   contigs (>= 25000 bp)   contigs (>= 50000 bp)  \
# count              475.000000              475.000000              475.000000
# mean             10121.960000             2392.606316              696.429474
# std               3434.749446             1119.104756              441.332950
# ...

# %%
print(data.columns)
data.describe()

# Créer les boxplots pour chaque colonne
plt.figure(figsize=(12, 8))
data[['Total length (>= 0 bp)',
       'Total length (>= 1000 bp)', 'Total length (>= 5000 bp)',
       'Total length (>= 10000 bp)', 'Total length (>= 25000 bp)',
       'Total length (>= 50000 bp)','Total length']].boxplot()
plt.xticks(rotation=90)  # Pour faire pivoter les étiquettes d'axe x si nécessaire
plt.title('Boxplot pour chaque colonne')
plt.xlabel('Colonnes')
plt.ylabel('Valeurs')
plt.grid(True)
plt.show()


# Créer les boxplots pour chaque colonne
plt.figure(figsize=(12, 8))
data[[' contigs (>= 0 bp)', ' contigs (>= 1000 bp)', ' contigs (>= 5000 bp)',
       ' contigs (>= 10000 bp)', ' contigs (>= 25000 bp)',
       ' contigs (>= 50000 bp)',' contigs', 'Largest contig']].boxplot()
plt.xticks(rotation=90)  # Pour faire pivoter les étiquettes d'axe x si nécessaire
plt.title('Boxplot pour chaque colonne')
plt.xlabel('Colonnes')
plt.ylabel('Valeurs')
plt.grid(True)
plt.show()

# Créer les boxplots pour chaque colonne
plt.figure(figsize=(12, 8))
data[['N50', 'N90']].boxplot()
plt.xticks(rotation=90)  # Pour faire pivoter les étiquettes d'axe x si nécessaire
plt.title('Boxplot pour chaque colonne')
plt.xlabel('Colonnes')
plt.ylabel('Valeurs')
plt.grid(True)
plt.show()

# Créer les boxplots pour chaque colonne
plt.figure(figsize=(12, 8))
data[['L50', 'L90']].boxplot()
plt.xticks(rotation=90)  # Pour faire pivoter les étiquettes d'axe x si nécessaire
plt.title('Boxplot pour chaque colonne')
plt.xlabel('Colonnes')
plt.ylabel('Valeurs')
plt.grid(True)
plt.show()
# Out:
# Index(['Fraction_Size', 'Depth', 'Lakes_names', 'Assembly',
#        ' contigs (>= 0 bp)', ' contigs (>= 1000 bp)', ' contigs (>= 5000 bp)',
#        ' contigs (>= 10000 bp)', ' contigs (>= 25000 bp)',
#        ' contigs (>= 50000 bp)', 'Total length (>= 0 bp)',
#        'Total length (>= 1000 bp)', 'Total length (>= 5000 bp)',
#        'Total length (>= 10000 bp)', 'Total length (>= 25000 bp)',
#        'Total length (>= 50000 bp)', ' contigs', 'Largest contig',
#        'Total length', 'N50', 'N90', 'auN', 'L50', 'L90', ' N's per 100 kbp'],
#       dtype='object')

# %%
data['Total length (>= 1000 bp)'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.hist(data['Total length (>= 1000 bp)'], bins = int((len(data['Total length (>= 1000 bp)']))/10), )
# Out:
# (array([ 1.,  0.,  1.,  1.,  1.,  0.,  1.,  2.,  1.,  2.,  4.,  1.,  6.,
#          7., 11., 15., 14., 17., 23., 30., 30., 34., 37., 28., 38., 33.,
#         33., 16., 26., 16.,  9.,  4.,  8.,  2.,  7.,  8.,  1.,  2.,  1.,
#          0.,  1.,  0.,  0.,  0.,  2.,  0.,  1.]),
#  array([3.77082500e+06, 4.68075337e+07, 8.98442424e+07, 1.32880951e+08,
#         1.75917660e+08, 2.18954369e+08, 2.61991077e+08, 3.05027786e+08,
#         3.48064495e+08, 3.91101204e+08, 4.34137912e+08, 4.77174621e+08,
#         5.20211330e+08, 5.63248038e+08, 6.06284747e+08, 6.49321456e+08,
#         6.92358165e+08, 7.35394873e+08, 7.78431582e+08, 8.21468291e+08,
#         8.64504999e+08, 9.07541708e+08, 9.50578417e+08, 9.93615126e+08,
#         1.03665183e+09, 1.07968854e+09, 1.12272525e+09, 1.16576196e+09,
#         1.20879867e+09, 1.25183538e+09, 1.29487209e+09, 1.33790880e+09,
#         1.38094550e+09, 1.42398221e+09, 1.46701892e+09, 1.51005563e+09,
# ...

# %%
Group = ['Fraction_Size', 'Depth', 'Lakes_names']
Plot = [' contigs (>= 0 bp)', ' contigs (>= 10000 bp)', 'Total length (>= 0 bp)', 'Total length (>= 10000 bp)',' contigs', 'Largest contig']

### ILLISIBLE ###
# for i in range(0,len(Group)):
#     for j in range(0,len(Plot)):
#         data.pivot(columns=Group[i], values=Plot[j]).plot.hist()
#         title = str("Histogramme of the")+ str(Plot[j]) + str(" colored by group of the") + str(Group[i])
#         plt.title(title)
#         plt.legend(title=Group[i], fontsize='small', bbox_to_anchor=(1.05, 1), loc='upper left', ncols = 3)
#         plt.show()

# %%
import matplotlib as mpl
Group = ['Fraction_Size', 'Depth', 'Lakes_names']
Plot = [' contigs (>= 0 bp)', ' contigs (>= 10000 bp)', 'Total length (>= 0 bp)', 'Total length (>= 10000 bp)',' contigs', 'Largest contig']
for i in range(0, len(Group)):
    for j in range(0, len(Plot)):
        if i >= 2:
            mpl.rcParams['figure.dpi'] = 150
        
        else :
            mpl.rcParams['figure.dpi'] = 80
        plt.figure(figsize=(2000, 1000))
        boxplot = data.boxplot(column=Plot[j], by=Group[i])
        plt.title('Boxplot of' + str(Plot[j]) + ' group by' + str(Group[i]))
        plt.xlabel(str(Group[i]))
        plt.ylabel(str(Plot[j]))
        if i >= 2:
            plt.xticks(rotation=90)
            plt.xticks(fontsize=5)

        plt.suptitle('')  # Pour supprimer le titre automatiquement ajouté par Pandas
        plt.show()

# %%
Group = ['Fraction_Size', 'Depth']
Plot = [' contigs (>= 0 bp)', ' contigs (>= 10000 bp)', 'Total length (>= 0 bp)', 'Total length (>= 10000 bp)',' contigs', 'Largest contig']
for i in range(0, len(Group)):
    for j in range(0, len(Plot)):

        grouping = data[Group[i]].unique()

        # Créer un histogramme séparé pour chaque valeur unique de "Depth"
        plt.figure(figsize=(10, 6))

        for group in grouping:
            subset_data = data[data[Group[i]] == group]
            plt.hist(subset_data[Plot[j]], bins=20, alpha=0.5, label=f"{Group[i]} {group}")

        plt.xlabel(str(Plot[j]))
        plt.ylabel('Fréquence')
        plt.title('Histogramme of the ' +  str(Plot[j]) + ' colored by group of ' + str(Group[i]))
        plt.legend()
        plt.grid(True)

        # Afficher le graphique
        plt.show()

# %%
Group = ['Fraction_Size', 'Depth', 'Lakes_names']
Plot = [' contigs (>= 0 bp)', ' contigs (>= 10000 bp)', 'Total length (>= 0 bp)', 'Total length (>= 10000 bp)',' contigs', 'Largest contig']

axes = data[~data['Lakes_names'].isin(['RIMV'])].hist(['Total length (>= 10000 bp)'], by='Lakes_names',bins=10, yrot=90,sharex=True,sharey=True, figsize=(12,12))
plt.suptitle('Histogrammes de Total length (>= 10000 bp) par Lakes_names', fontsize=16, y=0.98)
for ax in axes.flatten():
    #ax.set_xlabel('Total length (>= 0 bp)')
    ax.set_ylabel('Count')

axes = data[~data['Lakes_names'].isin(['RIMV'])].hist([' contigs (>= 10000 bp)'], by='Lakes_names',bins=10, yrot=90,sharex=True,sharey=True, figsize=(12,12))
plt.suptitle("Histogrammes of the numbers of contigs (>= 10000 bp) per Lakes_names", fontsize=16, y=0.98)
for ax in axes.flatten():
    #ax.set_xlabel('Total length (>= 0 bp)')
    ax.set_ylabel('Count')

# %%
data[data['Lakes_names'].isin(['VELN'])]
# Out:
#     Fraction_Size Depth Lakes_names                             Assembly  \
# 495             L     M        VELN  VELNM-LM-28jul20.megahit.nv.contigs
# 496             S     M        VELN  VELNM-SM-07apr22.megahit.nv.contigs
# 497             S     M        VELN  VELNM-SM-28jul20.megahit.nv.contigs
#
#       contigs (>= 0 bp)   contigs (>= 1000 bp)   contigs (>= 5000 bp)  \
# 495           2561807.0               329093.0                23804.0
# 496           1835119.0               239216.0                23848.0
# 497           1738197.0               218792.0                22491.0
#
#       contigs (>= 10000 bp)   contigs (>= 25000 bp)   contigs (>= 50000 bp)  \
# 495                  8670.0                  2140.0                   601.0
# 496                  8643.0                  2073.0                   581.0
# 497                  8305.0                  2020.0                   544.0
#
#      ...  Total length (>= 50000 bp)    contigs  Largest contig  Total length  \
# ...

# %%
import matplotlib as mpl
Group = ['Depth', 'Lakes_names']
Plot = [' contigs (>= 10000 bp)', 'Total length (>= 10000 bp)']


mpl.rcParams['figure.dpi'] = 80


#Depth
plt.figure(figsize=(2000, 1000))
boxplot = data[data['Depth'].isin(['E', 'H'])].boxplot(column=' contigs (>= 10000 bp)', by='Depth')
plt.title("Boxplot of the number of contigs >= 10 000 bp group by depth")
plt.xlabel('Depth')
plt.ylabel("number of contigs >= 10 000 bp")
plt.suptitle('')  # Pour supprimer le titre automatiquement ajouté par Pandas
plt.show()

plt.figure(figsize=(2000, 1000))
boxplot = data[data['Depth'].isin(['E', 'H'])].boxplot(column='Total length (>= 10000 bp)', by='Depth')
plt.title("Boxplot of the Total length of contigs >= 10 000 bp group by depth")
plt.xlabel('Depth')
plt.ylabel("Total length of contigs >= 10 000 bp")
plt.suptitle('')  # Pour supprimer le titre automatiquement ajouté par Pandas
plt.show()

#Lakes Names
mpl.rcParams['figure.dpi'] = 150

plt.figure(figsize=(2000, 1000))
boxplot = data.boxplot(column=' contigs (>= 10000 bp)', by='Lakes_names')
plt.title("Boxplot of the number of contigs >= 10 000 bp group by Lakes")
plt.xlabel('Lakes Names')
plt.ylabel("Numbers of contigs >= 10 000 bp")
plt.suptitle('')  # Pour supprimer le titre automatiquement ajouté par Pandas
plt.xticks(rotation=90)
plt.xticks(fontsize=5)
plt.show()

plt.figure(figsize=(2000, 1000))
boxplot = data.boxplot(column='Total length (>= 10000 bp)', by='Lakes_names')
plt.title("Boxplot of the Total length of contigs >= 10 000 bp group by Lakes")
plt.xlabel('Lakes Names')
plt.ylabel("Total length of contigs >= 10 000 bp")
plt.suptitle('')  # Pour supprimer le titre automatiquement ajouté par Pandas
plt.xticks(rotation=90)
plt.xticks(fontsize=5)
plt.show()

# %%
# Sélectionner les lignes où la colonne "Depth" contient la lettre "M"
filtered_data = data[data['Depth'].str.contains('M')]

# Extraire tous les noms uniques des lacs dans les lignes filtrées
lakes_with_m = filtered_data['Lakes_names'].unique()

# Afficher les noms des lacs
data[data['Lakes_names'].isin(lakes_with_m)]
# Out:
#     Fraction_Size Depth Lakes_names                             Assembly  \
# 82              S     M        CLAY  CLAYM-SM-20sep21.megahit.nv.contigs
# 83              S     M        CLAY  CLAYM-SM-26may22.megahit.nv.contigs
# 97              S     M        EDVL  EDVLM-SM-20sep21.megahit.nv.contigs
# 98              S     M        EDVL  EDVLM-SM-26may22.megahit.nv.contigs
# 110             L     M        FERT  FERTM-LM-29jul20.megahit.nv.contigs
# 111             S     M        FERT  FERTM-SM-05apr22.megahit.nv.contigs
# 112             S     M        FERT  FERTM-SM-29jul20.megahit.nv.contigs
# 154             L     M        JIRK  JIRKM-LM-03jun20.megahit.nv.contigs
# 155             L     M        JIRK  JIRKM-LM-10aug20.megahit.nv.contigs
# 156             S     M        JIRK  JIRKM-SM-03jun20.megahit.nv.contigs
# 157             S     M        JIRK  JIRKM-SM-10aug20.megahit.nv.contigs
# 159             S     M        KAST  KASTM-SM-14sep21.megahit.nv.contigs
# ...

# %%
# Filtrer les données pour obtenir les lacs avec une profondeur "E" sans "H"
lakes_E_without_H = data[data['Depth'] == 'E'][~data['Lakes_names'].isin(data[data['Depth'] == 'H']['Lakes_names'])]['Lakes_names'].unique()

# Filtrer les données pour obtenir les lacs avec une profondeur "H" sans "E"
lakes_H_without_E = data[data['Depth'] == 'H'][~data['Lakes_names'].isin(data[data['Depth'] == 'E']['Lakes_names'])]['Lakes_names'].unique()

# Combiner les deux ensembles de noms de lac en un seul ensemble de noms de lac unique
unique_lakes_names = set(list(lakes_E_without_H) + list(lakes_H_without_E))

# Afficher les noms de lac uniques
print(lakes_H_without_E)
# Out:
# []
# C:\Users\clere\AppData\Local\Temp\ipykernel_21968\901144456.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   lakes_E_without_H = data[data['Depth'] == 'E'][~data['Lakes_names'].isin(data[data['Depth'] == 'H']['Lakes_names'])]['Lakes_names'].unique()
# C:\Users\clere\AppData\Local\Temp\ipykernel_21968\901144456.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   lakes_H_without_E = data[data['Depth'] == 'H'][~data['Lakes_names'].isin(data[data['Depth'] == 'E']['Lakes_names'])]['Lakes_names'].unique()

# %%
import matplotlib.pyplot as plt

# Créer un DataFrame pivot pour compter le nombre de lignes pour chaque combinaison de lac et de profondeur
pivot_data = data.pivot_table(index='Lakes_names', columns='Depth', aggfunc='size', fill_value=0)

# Tracer l'histogramme
plt.figure(figsize=(15, 8))

# Obtenir les noms de lac et les index pour les barres
lakes = pivot_data.index
x = range(len(lakes))

# Largeur de chaque barre
bar_width = 0.2

# Tracer les barres pour chaque profondeur
plt.bar(x, pivot_data['E'], width=bar_width, color='b', align='center', label='Depth E')
plt.bar([i + bar_width for i in x], pivot_data['H'], width=bar_width, color='r', align='center', label='Depth H')
plt.bar([i + 2 * bar_width for i in x], pivot_data['M'], width=bar_width, color='g', align='center', label='Depth M')

# Ajouter des étiquettes d'axe et un titre
plt.xlabel('Lacs')
plt.ylabel('Nombre de lignes')
plt.title('Nombre de lignes par lac et par profondeur')
plt.xticks([i + bar_width for i in x], lakes, rotation=90)
plt.legend()

plt.show()

# %%
import pandas as pd
import re

# Supposons que 'df' est votre DataFrame contenant la colonne 'Assembly'

# Définir une fonction pour extraire la date
def extract_date(assembly_string):
    date = assembly_string[9:16]
    return date

# Appliquer la fonction extract_date à la colonne 'Assembly' pour extraire la date
data['Date'] = data['Assembly'].apply(extract_date)
print(extract_date("AMADE-SM-01apr22.megahit.nv.contigs"))
# Afficher le DataFrame avec la nouvelle colonne 'Date'
data
# Out:
# 01apr22
#     Fraction_Size Depth Lakes_names                             Assembly  \
# 0               S     E        AMAD  AMADE-SM-01apr22.megahit.nv.contigs
# 1               S     E        AMAD  AMADE-SM-06sep21.megahit.nv.contigs
# 2               S     H        AMAD  AMADH-SM-01apr22.megahit.nv.contigs
# 3               S     H        AMAD  AMADH-SM-06sep21.megahit.nv.contigs
# 5               S     E        ARCA  ARCAE-SM-04apr22.megahit.nv.contigs
# ..            ...   ...         ...                                  ...
# 546             S     E        ZURI  ZURIE-SM-02sep20.megahit.nv.contigs
# 547             S     E        ZURI  ZURIE-SM-04may22.megahit.nv.contigs
# 548             L     H        ZURI  ZURIH-LM-02sep20.megahit.nv.contigs
# 549             S     H        ZURI  ZURIH-SM-02sep20.megahit.nv.contigs
# 550             S     H        ZURI  ZURIH-SM-04may22.megahit.nv.contigs
#
#       contigs (>= 0 bp)   contigs (>= 1000 bp)   contigs (>= 5000 bp)  \
# ...

# %%
data['Date_corrected'] = pd.to_datetime(data['Date'])
data
# Out:
# C:\Users\clere\AppData\Local\Temp\ipykernel_21968\2665990601.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Date_corrected'] = pd.to_datetime(data['Date'])
#     Fraction_Size Depth Lakes_names                             Assembly  \
# 0               S     E        AMAD  AMADE-SM-01apr22.megahit.nv.contigs
# 1               S     E        AMAD  AMADE-SM-06sep21.megahit.nv.contigs
# 2               S     H        AMAD  AMADH-SM-01apr22.megahit.nv.contigs
# 3               S     H        AMAD  AMADH-SM-06sep21.megahit.nv.contigs
# 5               S     E        ARCA  ARCAE-SM-04apr22.megahit.nv.contigs
# ..            ...   ...         ...                                  ...
# 546             S     E        ZURI  ZURIE-SM-02sep20.megahit.nv.contigs
# 547             S     E        ZURI  ZURIE-SM-04may22.megahit.nv.contigs
# ...

# %%
list(data.columns)
# Out:
# ['Fraction_Size',
#  'Depth',
#  'Lakes_names',
#  'Assembly',
#  ' contigs (>= 0 bp)',
#  ' contigs (>= 1000 bp)',
#  ' contigs (>= 5000 bp)',
#  ' contigs (>= 10000 bp)',
#  ' contigs (>= 25000 bp)',
#  ' contigs (>= 50000 bp)',
#  'Total length (>= 0 bp)',
#  'Total length (>= 1000 bp)',
#  'Total length (>= 5000 bp)',
#  'Total length (>= 10000 bp)',
#  'Total length (>= 25000 bp)',
#  'Total length (>= 50000 bp)',
#  ' contigs',
#  'Largest contig',
#  'Total length',
#  'N50',
#  'N90',
#  'auN',
#  'L50',
#  'L90',
#  " N's per 100 kbp",
#  'Date',
#  'Date_corrected']

# %%
len(list(data['Lakes_names'].unique()))
# Out:
# 77

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

def time_line(Lake):
    # Supposons que 'data' est votre DataFrame
    data_Lac = data[data['Lakes_names'] == Lake]
    data_Lac['Date'] = pd.to_datetime(data_Lac['Date'])

    df_sorted = data_Lac.sort_values(by='Date')

    # Mapper les catégories à des valeurs numériques pour 'Depth'
    depth_mapping = {'E': 0, 'H': 1, 'M': 2}
    df_sorted['Depth_Num'] = df_sorted['Depth'].map(depth_mapping)

    # Définir une condition pour les triangles
    triangle_condition = df_sorted['Fraction_Size'] == 'L'

    plt.figure(figsize=(10, 6))  # Définir la taille de la figure

    # Tracer les points avec la couleur basée sur 'Depth_Num'
    scatter = plt.scatter(df_sorted['Date'], df_sorted[' contigs (>= 10000 bp)'], c=df_sorted['Depth_Num'], cmap='viridis', s=30, label='S')

    # Tracer les triangles pour les points qui satisfont la condition
    plt.scatter(df_sorted[triangle_condition]['Date'], df_sorted[triangle_condition][' contigs (>= 10000 bp)'], c=df_sorted[triangle_condition]['Depth_Num'], cmap='viridis', s=100, label='L')

    # Ajouter une barre de couleur avec l'étiquette 'Depth'
    plt.colorbar(scatter, ticks=np.arange(len(depth_mapping)), label='Depth', format=plt.FuncFormatter(lambda val, pos: list(depth_mapping.keys())[list(depth_mapping.values()).index(val)]))

    plt.title('Number of contigs >= 10 000 pb through the time for the lake : ' + str(Lake))  # Titre du graphique
    plt.xlabel('Date')  # Label de l'axe x
    plt.ylabel('Nombre de contigs >= 10 000 pb')  # Label de l'axe y
    plt.xticks(rotation=45)  # Rotation des étiquettes de l'axe x pour une meilleure lisibilité
    plt.grid(True)  # Afficher une grille

    plt.legend()  # Afficher la légende
    plt.tight_layout()  # Ajuster automatiquement la disposition pour éviter que les étiquettes ne se chevauchent
    plt.show()

#for i in range(0,len(list(data['Lakes_names'].unique()))):
#    time_line(list(data['Lakes_names'].unique())[i])

time_line("RIMV")
# Out:
# C:\Users\clere\AppData\Local\Temp\ipykernel_21968\442370712.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data_Lac['Date'] = pd.to_datetime(data_Lac['Date'])
# C:\Users\clere\AppData\Local\Temp\ipykernel_21968\442370712.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_Lac['Date'] = pd.to_datetime(data_Lac['Date'])

# %%
Espece = pd.read_csv("out.txt", sep ="\t", header= 0)
Espece
# Out:
#                    sequence_id class_fst_stage class_snd_stage
# 0          AMADE-SM-01apr22-C1        bacteria             NaN
# 1          AMADE-SM-01apr22-C2        bacteria             NaN
# 2          AMADE-SM-01apr22-C3        bacteria             NaN
# 3          AMADE-SM-01apr22-C4        bacteria             NaN
# 4          AMADE-SM-01apr22-C5        bacteria             NaN
# ...                        ...             ...             ...
# 46187  AMADE-SM-01apr22-C45901       organelle         unknown
# 46188  AMADE-SM-01apr22-C45966       organelle         plastid
# 46189  AMADE-SM-01apr22-C45987       organelle         plastid
# 46190  AMADE-SM-01apr22-C46018       organelle         plastid
# 46191  AMADE-SM-01apr22-C46100       organelle         plastid
#
# [46192 rows x 3 columns]

# %%
Longueur = pd.read_csv("test.fa.fai", sep ="\t", header=None)
Longueur
# Out:
#                                  0       1           2   3   4
# 0              AMADE-SM-01apr22-C1  627298          21  60  61
# 1              AMADE-SM-01apr22-C2  541596      637795  60  61
# 2              AMADE-SM-01apr22-C3  431143     1188439  60  61
# 3              AMADE-SM-01apr22-C4  420808     1626789  60  61
# 4              AMADE-SM-01apr22-C5  374477     2054632  60  61
# ...                            ...     ...         ...  ..  ..
# 1774480  AMADE-SM-01apr22-C1774481     200  1493867198  60  61
# 1774481  AMADE-SM-01apr22-C1774482     200  1493867429  60  61
# 1774482  AMADE-SM-01apr22-C1774483     200  1493867660  60  61
# 1774483  AMADE-SM-01apr22-C1774484     200  1493867891  60  61
# 1774484  AMADE-SM-01apr22-C1774485     200  1493868122  60  61
#
# [1774485 rows x 5 columns]

# %%
Longueur = Longueur.rename(columns={0: "Contig", 1: "Length"})
Espece = Espece.rename(columns={Espece.columns[0]: "Contig"})

# %%
merged_df = pd.merge(Longueur, Espece, on="Contig")
merged_df.tail()
# Out:
#                         Contig  Length          2   3   4 class_fst_stage  \
# 46187  AMADE-SM-01apr22-C46188    3000  377111379  60  61        bacteria
# 46188  AMADE-SM-01apr22-C46189    3000  377114454  60  61         eukarya
# 46189  AMADE-SM-01apr22-C46190    3000  377117529  60  61        bacteria
# 46190  AMADE-SM-01apr22-C46191    3000  377120604  60  61        bacteria
# 46191  AMADE-SM-01apr22-C46192    3000  377123679  60  61        bacteria
#
#       class_snd_stage
# 46187             NaN
# 46188             NaN
# 46189             NaN
# 46190             NaN
# 46191             NaN

# %%
merged_df.loc[merged_df['Length'].idxmin()]
# Out:
# Contig             AMADE-SM-01apr22-C46173
# Length                                3000
# 2                                377065254
# 3                                       60
# 4                                       61
# class_fst_stage                   bacteria
# class_snd_stage                        NaN
# Name: 46172, dtype: object

# %%
import matplotlib as mpl


plt.figure(figsize=(2000, 1000))
boxplot = merged_df.boxplot(column='Length', by='class_fst_stage')
plt.title("Longueur des contigs en fonction du types déterminé")
plt.xlabel("Group")
plt.ylabel("Longueur")
plt.suptitle('')  # Pour supprimer le titre automatiquement ajouté par Pandas
plt.ylim(bottom=0, top=100000)
plt.show()


plt.figure(figsize=(2000, 1000))
boxplot = merged_df.boxplot(column='Length', by='class_snd_stage')
plt.title("Longueur des contigs en fonction du types déterminé")
plt.xlabel("Group")
plt.ylabel("Longueur")
plt.suptitle('')  # Pour supprimer le titre automatiquement ajouté par Pandas
plt.ylim(bottom=0, top=100000)
plt.show()

# %%
merged_df['class_snd_stage'] = merged_df['class_snd_stage'].fillna('None')
merged_df[merged_df['class_snd_stage'].str.contains('plastid')]
# Out:
#                         Contig  Length          2   3   4 class_fst_stage  \
# 129      AMADE-SM-01apr22-C130  101254   21248711  60  61       organelle
# 174      AMADE-SM-01apr22-C175   89169   25609387  60  61       organelle
# 295      AMADE-SM-01apr22-C296   69670   35284512  60  61       organelle
# 722      AMADE-SM-01apr22-C723   44949   59166742  60  61       organelle
# 739      AMADE-SM-01apr22-C740   44393   59940509  60  61       organelle
# ...                        ...     ...        ...  ..  ..             ...
# 45857  AMADE-SM-01apr22-C45858    3013  376094216  60  61       organelle
# 45965  AMADE-SM-01apr22-C45966    3009  376427597  60  61       organelle
# 45986  AMADE-SM-01apr22-C45987    3008  376492365  60  61       organelle
# 46017  AMADE-SM-01apr22-C46018    3006  376587945  60  61       organelle
# 46099  AMADE-SM-01apr22-C46100    3003  376840567  60  61       organelle
#
#       class_snd_stage
# 129           plastid
# 174           plastid
# ...

# %%
# Calculer la moyenne de la longueur en fonction des groupes de class_fst_stage
mean_length = merged_df.groupby('class_fst_stage')['Length'].mean()

# Calculer l'écart type de la longueur en fonction des groupes de class_fst_stage
std_length = merged_df.groupby('class_fst_stage')['Length'].std()

# Créer un DataFrame à partir des moyennes et des écart-types calculés
summary_df = pd.DataFrame({'Mean Length': mean_length, 'Std Length': std_length})
summary_df
# Out:
#                   Mean Length    Std Length
# class_fst_stage
# archaea           6779.254613   8347.589419
# bacteria          8454.919642  13490.091865
# eukarya           4668.658162   3765.754785
# organelle         6698.188433   8369.087698
# prokarya         18733.593830  20770.592043
# unknown          17467.250000  24100.895902

# %%
# Calculer la moyenne de la longueur en fonction des groupes de class_fst_stage
mean_length = merged_df.groupby('class_snd_stage')['Length'].mean()

# Calculer l'écart type de la longueur en fonction des groupes de class_fst_stage
std_length = merged_df.groupby('class_snd_stage')['Length'].std()

# Créer un DataFrame à partir des moyennes et des écart-types calculés
summary2_df = pd.DataFrame({'Mean Length': mean_length, 'Std Length': std_length})
summary2_df
# Out:
#                  Mean Length    Std Length
# class_snd_stage
# None             8020.998642  12807.363315
# mitochondrion    6892.115385   7501.036445
# plastid          6687.764411   8702.645648
# unknown          3690.857143    686.868844

# %%
data[data["Assembly"].str.contains("AMADE-SM-01apr22")]
# Out:
#   Fraction_Size Depth Lakes_names                             Assembly  \
# 0             S     E        AMAD  AMADE-SM-01apr22.megahit.nv.contigs
#
#     contigs (>= 0 bp)   contigs (>= 1000 bp)   contigs (>= 5000 bp)  \
# 0           1774485.0               278227.0                20575.0
#
#     contigs (>= 10000 bp)   contigs (>= 25000 bp)   contigs (>= 50000 bp)  \
# 0                  7829.0                  2000.0                   586.0
#
#    ...  Largest contig  Total length     N50    N90      auN       L50  \
# 0  ...        627298.0  1.083887e+09  1640.0  611.0  10482.1  126503.0
#
#         L90   N's per 100 kbp     Date  Date_corrected
# 0  596154.0               0.0  01apr22      2022-04-01
#
# [1 rows x 27 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

categorie_counts = merged_df['class_fst_stage'].value_counts()

# Créez un diagramme circulaire (camembert)
plt.figure(figsize=(4, 4))
plt.pie(categorie_counts, labels=categorie_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Assurez-vous que le camembert est un cercle
plt.title('Diagramme circulaire des catégories')
plt.show()

categorie_counts = merged_df['class_snd_stage'].value_counts()

# Créez un diagramme circulaire (camembert)
plt.figure(figsize=(4, 4))
plt.pie(categorie_counts, labels=categorie_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Assurez-vous que le camembert est un cercle
plt.title('Diagramme circulaire des catégories')
plt.show()

# %%
Espece2 = pd.read_csv("Outalllength.out", sep ="\t", header= 0)
Espece2.tail()
# Out:
# C:\Users\clere\AppData\Local\Temp\ipykernel_17684\231541965.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   Espece2 = pd.read_csv("Outalllength.out", sep ="\t", header= 0)
#                        sequence_id class_fst_stage class_snd_stage
# 1774480  AMADE-SM-01apr22-C1774333       organelle         unknown
# 1774481  AMADE-SM-01apr22-C1774367       organelle         plastid
# 1774482  AMADE-SM-01apr22-C1774386       organelle         plastid
# 1774483  AMADE-SM-01apr22-C1774399       organelle   mitochondrion
# 1774484  AMADE-SM-01apr22-C1774485       organelle         plastid

# %%
Espece2 = Espece2.rename(columns={Espece2.columns[0]: "Contig"})
merged_df2 = pd.merge(Longueur, Espece2, on="Contig")
merged_df2.tail()
# Out:
#                             Contig  Length           2   3   4  \
# 1774480  AMADE-SM-01apr22-C1774481     200  1493867198  60  61
# 1774481  AMADE-SM-01apr22-C1774482     200  1493867429  60  61
# 1774482  AMADE-SM-01apr22-C1774483     200  1493867660  60  61
# 1774483  AMADE-SM-01apr22-C1774484     200  1493867891  60  61
# 1774484  AMADE-SM-01apr22-C1774485     200  1493868122  60  61
#
#         class_fst_stage class_snd_stage
# 1774480         eukarya             NaN
# 1774481         eukarya             NaN
# 1774482        bacteria             NaN
# 1774483         eukarya             NaN
# 1774484       organelle         plastid

# %%
import matplotlib as mpl


plt.figure(figsize=(2000, 1000))
boxplot = merged_df2.boxplot(column='Length', by='class_fst_stage')
plt.title("Longueur des contigs en fonction du types déterminé")
plt.xlabel("Group")
plt.ylabel("Longueur")
plt.suptitle('')  # Pour supprimer le titre automatiquement ajouté par Pandas
plt.ylim(bottom=0, top=20000)
plt.show()


plt.figure(figsize=(2000, 1000))
boxplot = merged_df2.boxplot(column='Length', by='class_snd_stage')
plt.title("Longueur des contigs en fonction du types déterminé")
plt.xlabel("Group")
plt.ylabel("Longueur")
plt.suptitle('')  # Pour supprimer le titre automatiquement ajouté par Pandas
plt.ylim(bottom=0, top=10000)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

categorie_counts = merged_df2['class_fst_stage'].value_counts()

# Créez un diagramme circulaire (camembert)
plt.figure(figsize=(4, 4))
plt.pie(categorie_counts, labels=categorie_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Assurez-vous que le camembert est un cercle
plt.title('Diagramme circulaire des catégories')
plt.show()

categorie_counts = merged_df2['class_snd_stage'].value_counts()

# Créez un diagramme circulaire (camembert)
plt.figure(figsize=(4, 4))
plt.pie(categorie_counts, labels=categorie_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Assurez-vous que le camembert est un cercle
plt.title('Diagramme circulaire des catégories')
plt.show()

# %%
# Calculer la moyenne de la longueur en fonction des groupes de class_fst_stage
mean_length = merged_df2.groupby('class_fst_stage')['Length'].mean()

# Calculer l'écart type de la longueur en fonction des groupes de class_fst_stage
std_length = merged_df2.groupby('class_fst_stage')['Length'].std()

# Créer un DataFrame à partir des moyennes et des écart-types calculés
summary_df = pd.DataFrame({'Mean Length': mean_length, 'Std Length': std_length})
summary_df
# Out:
#                  Mean Length   Std Length
# class_fst_stage
# archaea           585.657090  1165.931547
# bacteria          908.970676  3003.419366
# eukarya           659.747062   739.982248
# organelle         640.727053  1386.563573
# prokarya         1012.031363  4483.563272
# unknown           814.977335  3890.309497

# %%
# Calculer la moyenne de la longueur en fonction des groupes de class_fst_stage
mean_length = merged_df2.groupby('class_snd_stage')['Length'].mean()

# Calculer l'écart type de la longueur en fonction des groupes de class_fst_stage
std_length = merged_df2.groupby('class_snd_stage')['Length'].std()

# Créer un DataFrame à partir des moyennes et des écart-types calculés
summary_df = pd.DataFrame({'Mean Length': mean_length, 'Std Length': std_length})
summary_df
# Out:
#                  Mean Length   Std Length
# class_snd_stage
# mitochondrion     598.711775  1103.885499
# plastid           669.797757  1549.005355
# unknown           526.846398   426.519382

# %%
Espece3 = pd.read_csv("Out5000", sep ="\t", header= 0)
Espece3 = Espece3.rename(columns={Espece3.columns[0]: "Contig"})
merged_df3 = pd.merge(Longueur, Espece3, on="Contig")
merged_df3.head()
# Out:
#                 Contig  Length        2   3   4 class_fst_stage  \
# 0  AMADE-SM-01apr22-C1  627298       21  60  61        bacteria
# 1  AMADE-SM-01apr22-C2  541596   637795  60  61        bacteria
# 2  AMADE-SM-01apr22-C3  431143  1188439  60  61        bacteria
# 3  AMADE-SM-01apr22-C4  420808  1626789  60  61        bacteria
# 4  AMADE-SM-01apr22-C5  374477  2054632  60  61        bacteria
#
#   class_snd_stage
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
import pandas as pd
import matplotlib.pyplot as plt

categorie_counts = merged_df3['class_fst_stage'].value_counts()

# Créez un diagramme circulaire (camembert)
plt.figure(figsize=(4, 4))
plt.pie(categorie_counts, labels=categorie_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Assurez-vous que le camembert est un cercle
plt.title('Diagramme circulaire des catégories')
plt.show()

categorie_counts = merged_df3['class_snd_stage'].value_counts()

# Créez un diagramme circulaire (camembert)
plt.figure(figsize=(4, 4))
plt.pie(categorie_counts, labels=categorie_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Assurez-vous que le camembert est un cercle
plt.title('Diagramme circulaire des catégories')
plt.show()

# %%
Espece4 = pd.read_csv("Out8000", sep ="\t", header= 0)
Espece4 = Espece4.rename(columns={Espece4.columns[0]: "Contig"})
merged_df4 = pd.merge(Longueur, Espece4, on="Contig")
merged_df4.head()
# Out:
#                 Contig  Length        2   3   4 class_fst_stage  \
# 0  AMADE-SM-01apr22-C1  627298       21  60  61        bacteria
# 1  AMADE-SM-01apr22-C2  541596   637795  60  61        bacteria
# 2  AMADE-SM-01apr22-C3  431143  1188439  60  61        bacteria
# 3  AMADE-SM-01apr22-C4  420808  1626789  60  61        bacteria
# 4  AMADE-SM-01apr22-C5  374477  2054632  60  61        bacteria
#
#   class_snd_stage
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
import pandas as pd
import matplotlib.pyplot as plt

categorie_counts = merged_df4['class_fst_stage'].value_counts()

# Créez un diagramme circulaire (camembert)
plt.figure(figsize=(4, 4))
plt.pie(categorie_counts, labels=categorie_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Assurez-vous que le camembert est un cercle
plt.title('Diagramme circulaire des catégories')
plt.show()

categorie_counts = merged_df4['class_snd_stage'].value_counts()

# Créez un diagramme circulaire (camembert)
plt.figure(figsize=(4, 4))
plt.pie(categorie_counts, labels=categorie_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Assurez-vous que le camembert est un cercle
plt.title('Diagramme circulaire des catégories')
plt.show()

# %%
Espece5 = pd.read_csv("Out10000", sep ="\t", header= 0)
Espece5 = Espece5.rename(columns={Espece5.columns[0]: "Contig"})
merged_df5 = pd.merge(Longueur, Espece5, on="Contig")
merged_df5.head()
# Out:
#                 Contig  Length        2   3   4 class_fst_stage  \
# 0  AMADE-SM-01apr22-C1  627298       21  60  61        bacteria
# 1  AMADE-SM-01apr22-C2  541596   637795  60  61        bacteria
# 2  AMADE-SM-01apr22-C3  431143  1188439  60  61        bacteria
# 3  AMADE-SM-01apr22-C4  420808  1626789  60  61        bacteria
# 4  AMADE-SM-01apr22-C5  374477  2054632  60  61        bacteria
#
#   class_snd_stage
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
import pandas as pd
import matplotlib.pyplot as plt

categorie_counts = merged_df5['class_fst_stage'].value_counts()

# Créez un diagramme circulaire (camembert)
plt.figure(figsize=(4, 4))
plt.pie(categorie_counts, labels=categorie_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Assurez-vous que le camembert est un cercle
plt.title('Diagramme circulaire des catégories')
plt.show()

categorie_counts = merged_df5['class_snd_stage'].value_counts()

# Créez un diagramme circulaire (camembert)
plt.figure(figsize=(4, 4))
plt.pie(categorie_counts, labels=categorie_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Assurez-vous que le camembert est un cercle
plt.title('Diagramme circulaire des catégories')
plt.show()

# %%
Long = [0, 5000, 10000, 50000,60000,70000,80000,90000, 100000,200000, 300000,400000, 500000,600000]

Bact = [0] *len(Long)
Eukarya = [0] *len(Long)
Proc = [0] *len(Long)
Archaea = [0] *len(Long)
Organelle = [0] *len(Long)

Plastid = [0] *len(Long)
Mitoc = [0] *len(Long)
merged_df2.tail(20)
# Out:
#                             Contig  Length           2   3   4  \
# 1774465  AMADE-SM-01apr22-C1774466     200  1493863733  60  61
# 1774466  AMADE-SM-01apr22-C1774467     200  1493863964  60  61
# 1774467  AMADE-SM-01apr22-C1774468     200  1493864195  60  61
# 1774468  AMADE-SM-01apr22-C1774469     200  1493864426  60  61
# 1774469  AMADE-SM-01apr22-C1774470     200  1493864657  60  61
# 1774470  AMADE-SM-01apr22-C1774471     200  1493864888  60  61
# 1774471  AMADE-SM-01apr22-C1774472     200  1493865119  60  61
# 1774472  AMADE-SM-01apr22-C1774473     200  1493865350  60  61
# 1774473  AMADE-SM-01apr22-C1774474     200  1493865581  60  61
# 1774474  AMADE-SM-01apr22-C1774475     200  1493865812  60  61
# 1774475  AMADE-SM-01apr22-C1774476     200  1493866043  60  61
# 1774476  AMADE-SM-01apr22-C1774477     200  1493866274  60  61
# 1774477  AMADE-SM-01apr22-C1774478     200  1493866505  60  61
# 1774478  AMADE-SM-01apr22-C1774479     200  1493866736  60  61
# ...

# %%
plt.plot(Long, Bact, label ='Bacteria')
plt.plot(Long, Eukarya, label ='Eukarya')
plt.plot(Long, Proc, label ='Prokarya')
plt.plot(Long, Archaea, label ='Archaea')
plt.plot(Long, Organelle, label ='Organelle')
plt.legend()
plt.show()

plt.plot(Long, Plastid, label ='Plastid')
plt.plot(Long, Mitoc, label ='Mitochondrion')
plt.legend()
plt.show()

#Percentage

Bact100 = [0]*len(Long)
Eukarya100 = [0]*len(Long)
Proc100 = [0]*len(Long)
Archaea100 = [0]*len(Long)
Organelle100 = [0]*len(Long)

Plastid100 = [0]*len(Long)
Mitoc100 = [0]*len(Long)

for i in range(0, len(Long)):
    Bact100[i] = Bact[i]/(Bact[i] + Eukarya[i] + Proc[i] + Archaea[i] + Organelle[i]+0.00001)
    Proc100[i] = Proc[i]/(Bact[i] + Eukarya[i] + Proc[i] + Archaea[i] + Organelle[i]+0.00001)
    Eukarya100[i] = Eukarya[i]/(Bact[i] + Eukarya[i] + Proc[i] + Archaea[i] + Organelle[i]+0.00001)
    Archaea100[i] = Archaea[i]/(Bact[i] + Eukarya[i] + Proc[i] + Archaea[i] + Organelle[i]+0.00001)
    Organelle100[i] = Organelle[i]/(Bact[i] + Eukarya[i] + Proc[i] + Archaea[i] + Organelle[i]+0.00001)

    Mitoc100[i] = Mitoc[i]/(Mitoc[i] + Plastid[i]+1)
    Plastid100[i] = Plastid[i]/(Mitoc[i] + Plastid[i]+1)


plt.plot(Long, Bact100, label ='Bacteria')
plt.plot(Long, Eukarya100, label ='Eukarya')
plt.plot(Long, Proc100, label ='Prokarya')
plt.plot(Long, Archaea100, label ='Archaea')
plt.plot(Long, Organelle100, label ='Organelle')
plt.legend()
plt.show()

plt.plot(Long, Plastid100, label ='Plastid')
plt.plot(Long, Mitoc100, label ='Mitochondrion')
plt.legend()
plt.show()

# %%
#merged_df2['Length']
for i in range(0,len(Long)):
    Bact[i] = (merged_df2[(merged_df2["class_fst_stage"] == "bacteria") & (merged_df2["Length"] >= Long[i])].shape[0] / merged_df2[merged_df2["Length"] > Long[i]].shape[0]+0.01) *100
    Eukarya[i] = (merged_df2[(merged_df2["class_fst_stage"] == "eukarya") & (merged_df2["Length"] >= Long[i])].shape[0] / merged_df2[merged_df2["Length"] > Long[i]].shape[0]+0.01) *100
    Proc[i] = (merged_df2[(merged_df2["class_fst_stage"] == "prokarya") & (merged_df2["Length"] >= Long[i])].shape[0] / merged_df2[merged_df2["Length"] > Long[i]].shape[0]+0.01) *100
    Archaea[i] = (merged_df2[(merged_df2["class_fst_stage"] == "archaea") & (merged_df2["Length"] >= Long[i])].shape[0] / merged_df2[merged_df2["Length"] > Long[i]].shape[0]+0.01) *100
    Organelle[i]  = (merged_df2[(merged_df2["class_fst_stage"] == "organelle") & (merged_df2["Length"] >= Long[i])].shape[0] / merged_df2[merged_df2["Length"] > Long[i]].shape[0]+0.01) *100

    Plastid[i] = (merged_df2[(merged_df2["class_fst_stage"] == "organelle") & (merged_df2["Length"] >= Long[i]) & (merged_df2["class_snd_stage"] == "plastid")].shape[0] / ((merged_df2[(merged_df2["Length"] > Long[i]) & (merged_df2["class_fst_stage"] == "organelle")].shape[0])+0.01)) *100
    Mitoc[i] = (merged_df2[(merged_df2["class_fst_stage"] == "organelle") & (merged_df2["Length"] >= Long[i]) & (merged_df2["class_snd_stage"] == "mitochondrion")].shape[0] / ((merged_df2[(merged_df2["Length"] > Long[i]) & (merged_df2["class_fst_stage"] == "organelle")].shape[0])+0.01)) *100

# %%
plt.plot(Long, Bact, label ='Bacteria')
plt.plot(Long, Eukarya, label ='Eukarya')
plt.plot(Long, Proc, label ='Prokarya')
plt.plot(Long, Archaea, label ='Archaea')
plt.plot(Long, Organelle, label ='Organelle')
plt.legend()
plt.show()

plt.plot(Long, Plastid, label ='Plastid')
plt.plot(Long, Mitoc, label ='Mitochondrion')
plt.legend()
plt.show()

# %%
Long = [0, 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000]

Bact = [0]*len(Long)
Eukarya = [0]*len(Long)
Proc = [0]*len(Long)
Archaea = [0]*len(Long)
Organelle = [0]*len(Long)

Plastid = [0]*len(Long)
Mitoc = [0]*len(Long)

# %%
for i in range(0,len(Long)):
    Bact[i] = merged_df2[(merged_df2["class_fst_stage"] == "bacteria") & (merged_df2["Length"] >= Long[i])].shape[0]
    Eukarya[i] = merged_df2[(merged_df2["class_fst_stage"] == "eukarya") & (merged_df2["Length"] >= Long[i])].shape[0]
    Proc[i] = merged_df2[(merged_df2["class_fst_stage"] == "prokarya") & (merged_df2["Length"] >= Long[i])].shape[0]
    Archaea[i] = merged_df2[(merged_df2["class_fst_stage"] == "archaea") & (merged_df2["Length"] >= Long[i])].shape[0] 
    Organelle[i]  = merged_df2[(merged_df2["class_fst_stage"] == "organelle") & (merged_df2["Length"] >= Long[i])].shape[0]

    Plastid[i] = merged_df2[(merged_df2["class_fst_stage"] == "organelle") & (merged_df2["Length"] >= Long[i]) & (merged_df2["class_snd_stage"] == "plastid")].shape[0]
    Mitoc[i] = merged_df2[(merged_df2["class_fst_stage"] == "organelle") & (merged_df2["Length"] >= Long[i]) & (merged_df2["class_snd_stage"] == "mitochondrion")].shape[0]

# %%
plt.plot(Long, Bact, label ='Bacteria')
plt.plot(Long, Eukarya, label ='Eukarya')
plt.plot(Long, Proc, label ='Prokarya')
plt.plot(Long, Archaea, label ='Archaea')
plt.plot(Long, Organelle, label ='Organelle')
plt.legend()
plt.show()

plt.plot(Long, Plastid, label ='Plastid')
plt.plot(Long, Mitoc, label ='Mitochondrion')
plt.legend()
plt.show()
